# %%
import pandas as pd
from datetime import datetime

# %%
#import the data file for KSI - Killed or Seriously Injured from the Toronto Police Service webstie
data = pd.read_csv('KSI.csv')

# %%
#Print out the data to have a look at the data
data
# Out:
#          Index_      ACCNUM  YEAR           DATE  TIME  Hour  \
# 0       5245961     1107460  2009  1245643200000     0     0
# 1       5245962     1107460  2009  1245643200000     0     0
# 2       6120124     1158873  2010  1269403200000     0     0
# 3       6120125     1158873  2010  1269403200000     0     0
# 4       6120126     1158873  2010  1269403200000     0     0
# ...         ...         ...   ...            ...   ...   ...
# 12239  80221346  4003176267  2014  1414296000000  2335    23
# 12240  80221347  4003176267  2014  1414296000000  2335    23
# 12241  80221348  4003176267  2014  1414296000000  2335    23
# 12242  80221349  4003176267  2014  1414296000000  2335    23
# 12243  80491737  5001874738  2015  1446264000000  2335    23
#
#                   STREET1           STREET2        OFFSET      ROAD_CLASS  \
# 0      F G GARDINER XY  E       KIPLING AVE                    Expressway
# 1      F G GARDINER XY  E       KIPLING AVE                    Expressway
# 2         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# 3         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# 4         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# ...                   ...               ...           ...             ...
# 12239   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12240   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12241   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12242   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12243        WOODBINE AVE   STRATHMORE BLVD                Major Arterial
#
#        ... EMERG_VEH  PASSENGER  SPEEDING  AG_DRIV REDLIGHT  ALCOHOL  \
# 0      ...                            Yes      Yes
# 1      ...                            Yes      Yes
# 2      ...
# 3      ...
# 4      ...
# ...    ...       ...        ...       ...      ...      ...      ...
# 12239  ...                            Yes      Yes
# 12240  ...                            Yes      Yes
# 12241  ...                            Yes      Yes
# 12242  ...                            Yes      Yes
# 12243  ...                            Yes      Yes
#
#        DISABILITY  Hood_ID                                Neighbourh ObjectId
# 0                       17  Mimico (includes Humber Bay Shores) (17)        1
# 1                       17  Mimico (includes Humber Bay Shores) (17)        2
# 2                      131                               Rouge (131)        3
# 3                      131                               Rouge (131)        4
# 4                      131                               Rouge (131)        5
# ...           ...      ...                                       ...      ...
# 12239                   77    Waterfront Communities-The Island (77)    12240
# 12240                   77    Waterfront Communities-The Island (77)    12241
# 12241                   77    Waterfront Communities-The Island (77)    12242
# 12242                   77    Waterfront Communities-The Island (77)    12243
# 12243                   60                     Woodbine-Lumsden (60)    12244
#
# [12244 rows x 58 columns]

# %%
#As we notice the DATE columns is in UNIX timestamp, we will convert it into normal date format. 
#Since we are only analyzing accidents in Toronto, we only need one timezone.
data['DATE'] = data['DATE'].div(1000)

# %%
data
# Out:
#          Index_      ACCNUM  YEAR          DATE  TIME  Hour  \
# 0       5245961     1107460  2009  1.245643e+09     0     0
# 1       5245962     1107460  2009  1.245643e+09     0     0
# 2       6120124     1158873  2010  1.269403e+09     0     0
# 3       6120125     1158873  2010  1.269403e+09     0     0
# 4       6120126     1158873  2010  1.269403e+09     0     0
# ...         ...         ...   ...           ...   ...   ...
# 12239  80221346  4003176267  2014  1.414296e+09  2335    23
# 12240  80221347  4003176267  2014  1.414296e+09  2335    23
# 12241  80221348  4003176267  2014  1.414296e+09  2335    23
# 12242  80221349  4003176267  2014  1.414296e+09  2335    23
# 12243  80491737  5001874738  2015  1.446264e+09  2335    23
#
#                   STREET1           STREET2        OFFSET      ROAD_CLASS  \
# 0      F G GARDINER XY  E       KIPLING AVE                    Expressway
# 1      F G GARDINER XY  E       KIPLING AVE                    Expressway
# 2         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# 3         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# 4         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# ...                   ...               ...           ...             ...
# 12239   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12240   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12241   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12242   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12243        WOODBINE AVE   STRATHMORE BLVD                Major Arterial
#
#        ... EMERG_VEH  PASSENGER  SPEEDING  AG_DRIV REDLIGHT  ALCOHOL  \
# 0      ...                            Yes      Yes
# 1      ...                            Yes      Yes
# 2      ...
# 3      ...
# 4      ...
# ...    ...       ...        ...       ...      ...      ...      ...
# 12239  ...                            Yes      Yes
# 12240  ...                            Yes      Yes
# 12241  ...                            Yes      Yes
# 12242  ...                            Yes      Yes
# 12243  ...                            Yes      Yes
#
#        DISABILITY  Hood_ID                                Neighbourh ObjectId
# 0                       17  Mimico (includes Humber Bay Shores) (17)        1
# 1                       17  Mimico (includes Humber Bay Shores) (17)        2
# 2                      131                               Rouge (131)        3
# 3                      131                               Rouge (131)        4
# 4                      131                               Rouge (131)        5
# ...           ...      ...                                       ...      ...
# 12239                   77    Waterfront Communities-The Island (77)    12240
# 12240                   77    Waterfront Communities-The Island (77)    12241
# 12241                   77    Waterfront Communities-The Island (77)    12242
# 12242                   77    Waterfront Communities-The Island (77)    12243
# 12243                   60                     Woodbine-Lumsden (60)    12244
#
# [12244 rows x 58 columns]

# %%
data['DATE'] = pd.to_datetime(data['DATE'], unit = 's')

# %%
data
# Out:
#          Index_      ACCNUM  YEAR                DATE  TIME  Hour  \
# 0       5245961     1107460  2009 2009-06-22 04:00:00     0     0
# 1       5245962     1107460  2009 2009-06-22 04:00:00     0     0
# 2       6120124     1158873  2010 2010-03-24 04:00:00     0     0
# 3       6120125     1158873  2010 2010-03-24 04:00:00     0     0
# 4       6120126     1158873  2010 2010-03-24 04:00:00     0     0
# ...         ...         ...   ...                 ...   ...   ...
# 12239  80221346  4003176267  2014 2014-10-26 04:00:00  2335    23
# 12240  80221347  4003176267  2014 2014-10-26 04:00:00  2335    23
# 12241  80221348  4003176267  2014 2014-10-26 04:00:00  2335    23
# 12242  80221349  4003176267  2014 2014-10-26 04:00:00  2335    23
# 12243  80491737  5001874738  2015 2015-10-31 04:00:00  2335    23
#
#                   STREET1           STREET2        OFFSET      ROAD_CLASS  \
# 0      F G GARDINER XY  E       KIPLING AVE                    Expressway
# 1      F G GARDINER XY  E       KIPLING AVE                    Expressway
# 2         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# 3         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# 4         SHEPPARD Aven E  TWYN RIVERS Driv                Minor Arterial
# ...                   ...               ...           ...             ...
# 12239   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12240   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12241   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12242   LAKE SHORE BLVD E   LOWER JARVIS ST  27 m East of      Expressway
# 12243        WOODBINE AVE   STRATHMORE BLVD                Major Arterial
#
#        ... EMERG_VEH  PASSENGER  SPEEDING  AG_DRIV REDLIGHT  ALCOHOL  \
# 0      ...                            Yes      Yes
# 1      ...                            Yes      Yes
# 2      ...
# 3      ...
# 4      ...
# ...    ...       ...        ...       ...      ...      ...      ...
# 12239  ...                            Yes      Yes
# 12240  ...                            Yes      Yes
# 12241  ...                            Yes      Yes
# 12242  ...                            Yes      Yes
# 12243  ...                            Yes      Yes
#
#        DISABILITY  Hood_ID                                Neighbourh ObjectId
# 0                       17  Mimico (includes Humber Bay Shores) (17)        1
# 1                       17  Mimico (includes Humber Bay Shores) (17)        2
# 2                      131                               Rouge (131)        3
# 3                      131                               Rouge (131)        4
# 4                      131                               Rouge (131)        5
# ...           ...      ...                                       ...      ...
# 12239                   77    Waterfront Communities-The Island (77)    12240
# 12240                   77    Waterfront Communities-The Island (77)    12241
# 12241                   77    Waterfront Communities-The Island (77)    12242
# 12242                   77    Waterfront Communities-The Island (77)    12243
# 12243                   60                     Woodbine-Lumsden (60)    12244
#
# [12244 rows x 58 columns]
